# %%
import pandas as pd
from datetime import datetime

path = "machine_learning_docs/melb_data.csv"

collisions = pd.read_csv(r"C:\Users\honzi\OneDrive\Desktop\py_osobni\machine_learning_docs\Traffic_Crashes_-_Crashes.csv")

print(collisions.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 832299 entries, 0 to 832298
# Data columns (total 48 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   CRASH_RECORD_ID                832299 non-null  object
#  1   CRASH_DATE_EST_I               62073 non-null   object
#  2   CRASH_DATE                     832299 non-null  object
#  3   POSTED_SPEED_LIMIT             832299 non-null  int64
#  4   TRAFFIC_CONTROL_DEVICE         832299 non-null  object
#  5   DEVICE_CONDITION               832299 non-null  object
#  6   WEATHER_CONDITION              832299 non-null  object
#  7   LIGHTING_CONDITION             832299 non-null  object
#  8   FIRST_CRASH_TYPE               832299 non-null  object
#  9   TRAFFICWAY_TYPE                832299 non-null  object
#  10  LANE_CNT                       199011 non-null  float64
#  11  ALIGNMENT                      832299 non-null  object
#  12  ROADWAY_SURFACE_COND           832299 non-null  object
#  13  ROAD_DEFECT                    832299 non-null  object
#  14  REPORT_TYPE                    807355 non-null  object
#  15  CRASH_TYPE                     832299 non-null  object
#  16  INTERSECTION_RELATED_I         190820 non-null  object
#  17  NOT_RIGHT_OF_WAY_I             38306 non-null   object
#  18  HIT_AND_RUN_I                  260617 non-null  object
#  19  DAMAGE                         832299 non-null  object
#  20  DATE_POLICE_NOTIFIED           832299 non-null  object
#  21  PRIM_CONTRIBUTORY_CAUSE        832299 non-null  object
#  22  SEC_CONTRIBUTORY_CAUSE         832299 non-null  object
#  23  STREET_NO                      832299 non-null  int64
#  24  STREET_DIRECTION               832295 non-null  object
#  25  STREET_NAME                    832298 non-null  object
#  26  BEAT_OF_OCCURRENCE             832294 non-null  float64
#  27  PHOTOS_TAKEN_I                 11043 non-null   object
#  28  STATEMENTS_TAKEN_I             18707 non-null   object
#  29  DOORING_I                      2556 non-null    object
#  30  WORK_ZONE_I                    4731 non-null    object
#  31  WORK_ZONE_TYPE                 3652 non-null    object
#  32  WORKERS_PRESENT_I              1213 non-null    object
#  33  NUM_UNITS                      832299 non-null  int64
#  34  MOST_SEVERE_INJURY             830470 non-null  object
#  35  INJURIES_TOTAL                 830483 non-null  float64
#  36  INJURIES_FATAL                 830483 non-null  float64
#  37  INJURIES_INCAPACITATING        830483 non-null  float64
#  38  INJURIES_NON_INCAPACITATING    830483 non-null  float64
#  39  INJURIES_REPORTED_NOT_EVIDENT  830483 non-null  float64
#  40  INJURIES_NO_INDICATION         830483 non-null  float64
#  41  INJURIES_UNKNOWN               830483 non-null  float64
#  42  CRASH_HOUR                     832299 non-null  int64
#  43  CRASH_DAY_OF_WEEK              832299 non-null  int64
#  44  CRASH_MONTH                    832299 non-null  int64
#  45  LATITUDE                       826527 non-null  float64
#  46  LONGITUDE                      826527 non-null  float64
#  47  LOCATION                       826527 non-null  object
# dtypes: float64(11), int64(6), object(31)
# memory usage: 304.8+ MB
# None

# %%
print(collisions.columns)
print(collisions.isna().sum())
# Out:
# Index(['CRASH_RECORD_ID', 'CRASH_DATE_EST_I', 'CRASH_DATE',
#        'POSTED_SPEED_LIMIT', 'TRAFFIC_CONTROL_DEVICE', 'DEVICE_CONDITION',
#        'WEATHER_CONDITION', 'LIGHTING_CONDITION', 'FIRST_CRASH_TYPE',
#        'TRAFFICWAY_TYPE', 'LANE_CNT', 'ALIGNMENT', 'ROADWAY_SURFACE_COND',
#        'ROAD_DEFECT', 'REPORT_TYPE', 'CRASH_TYPE', 'INTERSECTION_RELATED_I',
#        'NOT_RIGHT_OF_WAY_I', 'HIT_AND_RUN_I', 'DAMAGE', 'DATE_POLICE_NOTIFIED',
#        'PRIM_CONTRIBUTORY_CAUSE', 'SEC_CONTRIBUTORY_CAUSE', 'STREET_NO',
#        'STREET_DIRECTION', 'STREET_NAME', 'BEAT_OF_OCCURRENCE',
#        'PHOTOS_TAKEN_I', 'STATEMENTS_TAKEN_I', 'DOORING_I', 'WORK_ZONE_I',
#        'WORK_ZONE_TYPE', 'WORKERS_PRESENT_I', 'NUM_UNITS',
#        'MOST_SEVERE_INJURY', 'INJURIES_TOTAL', 'INJURIES_FATAL',
#        'INJURIES_INCAPACITATING', 'INJURIES_NON_INCAPACITATING',
#        'INJURIES_REPORTED_NOT_EVIDENT', 'INJURIES_NO_INDICATION',
#        'INJURIES_UNKNOWN', 'CRASH_HOUR', 'CRASH_DAY_OF_WEEK', 'CRASH_MONTH',
#        'LATITUDE', 'LONGITUDE', 'LOCATION'],
#       dtype='object')
# CRASH_RECORD_ID                       0
# CRASH_DATE_EST_I                 770226
# CRASH_DATE                            0
# POSTED_SPEED_LIMIT                    0
# TRAFFIC_CONTROL_DEVICE                0
# DEVICE_CONDITION                      0
# WEATHER_CONDITION                     0
# LIGHTING_CONDITION                    0
# FIRST_CRASH_TYPE                      0
# TRAFFICWAY_TYPE                       0
# LANE_CNT                         633288
# ALIGNMENT                             0
# ROADWAY_SURFACE_COND                  0
# ROAD_DEFECT                           0
# REPORT_TYPE                       24944
# CRASH_TYPE                            0
# INTERSECTION_RELATED_I           641479
# NOT_RIGHT_OF_WAY_I               793993
# HIT_AND_RUN_I                    571682
# DAMAGE                                0
# DATE_POLICE_NOTIFIED                  0
# PRIM_CONTRIBUTORY_CAUSE               0
# SEC_CONTRIBUTORY_CAUSE                0
# STREET_NO                             0
# STREET_DIRECTION                      4
# STREET_NAME                           1
# BEAT_OF_OCCURRENCE                    5
# PHOTOS_TAKEN_I                   821256
# STATEMENTS_TAKEN_I               813592
# DOORING_I                        829743
# WORK_ZONE_I                      827568
# WORK_ZONE_TYPE                   828647
# WORKERS_PRESENT_I                831086
# NUM_UNITS                             0
# MOST_SEVERE_INJURY                 1829
# INJURIES_TOTAL                     1816
# INJURIES_FATAL                     1816
# INJURIES_INCAPACITATING            1816
# INJURIES_NON_INCAPACITATING        1816
# INJURIES_REPORTED_NOT_EVIDENT      1816
# INJURIES_NO_INDICATION             1816
# INJURIES_UNKNOWN                   1816
# CRASH_HOUR                            0
# CRASH_DAY_OF_WEEK                     0
# CRASH_MONTH                           0
# LATITUDE                           5772
# LONGITUDE                          5772
# LOCATION                           5772
# dtype: int64

# %%
#Check if there are no duplicate crash ID´s"
collisions["CRASH_RECORD_ID"].is_unique

#Simplify dates
collisions["CRASH_DATE"] = pd.to_datetime(collisions["CRASH_DATE"])
collisions["CRASH_DATE"] = collisions["CRASH_DATE"].dt.date

collisions["DATE_POLICE_NOTIFIED"] = pd.to_datetime(collisions["DATE_POLICE_NOTIFIED"])
collisions["DATE_POLICE_NOTIFIED"] = collisions["DATE_POLICE_NOTIFIED"].dt.date

# Define the cutoff date (start of 2017)
cutoff_date = datetime(2017, 1, 1).date()

# Filter the dataframe to keep only dates from 2017 and above
collisions = collisions[collisions["CRASH_DATE"] >= cutoff_date]


# Drop useless columns
collisions_cleaned = collisions.drop(["CRASH_RECORD_ID",
                                    "CRASH_DATE_EST_I",
                                    "LANE_CNT",
                                    "NOT_RIGHT_OF_WAY_I",
                                    "PHOTOS_TAKEN_I",
                                    "STATEMENTS_TAKEN_I",
                                    "DOORING_I",
                                    "WORK_ZONE_I",
                                    "WORK_ZONE_TYPE",
                                    "WORKERS_PRESENT_I",
                                    "BEAT_OF_OCCURRENCE",
                                    "INTERSECTION_RELATED_I"],axis = 1)
# Convert floats to integers
columns_to_convert = [
    "INJURIES_TOTAL",
    "INJURIES_FATAL",
    "INJURIES_INCAPACITATING",
    "INJURIES_NON_INCAPACITATING",
    "INJURIES_REPORTED_NOT_EVIDENT",
    "INJURIES_NO_INDICATION",
    "INJURIES_UNKNOWN"
]

collisions_cleaned = collisions_cleaned.dropna(subset = columns_to_convert)
collisions_cleaned[columns_to_convert] = collisions_cleaned[columns_to_convert].astype("int64")

# Drop rows when location is unknown
rows_to_drop = [
    "LONGITUDE",
    "LATITUDE",
    "LOCATION"
]
collisions_cleaned = collisions_cleaned.dropna(subset = rows_to_drop)

# Adjust total cost
to_replace_small_damage = "$0 - $500"
to_replace_big_damage = "$1500+"

collisions_cleaned['DAMAGE'] = collisions_cleaned['DAMAGE'].replace("$500 OR LESS", to_replace_small_damage)
collisions_cleaned['DAMAGE'] = collisions_cleaned['DAMAGE'].replace("OVER $1,500", to_replace_big_damage)

# Change wording
to_replace_desk_report = "DESK REPORT"

collisions_cleaned["REPORT_TYPE"] = collisions_cleaned["REPORT_TYPE"].replace("NOT ON SCENE (DESK REPORT)",to_replace_desk_report)

to_replace_crash_type = "INJURY / TOW DUE TO CRASH"

collisions_cleaned["CRASH_TYPE"] = collisions_cleaned["CRASH_TYPE"].replace("INJURY AND / OR TOW DUE TO CRASH", to_replace_crash_type)


# Fill missing values with N
collisions_cleaned['HIT_AND_RUN_I'].fillna('N', inplace=True)

# Assign days to numbers
day_mapping = {
    1: "Sunday",
    2: "Monday",
    3: "Tuesday",
    4: "Wednesday",
    5: "Thursday",
    6: "Friday",
    7: "Saturday"
}

collisions_cleaned["CRASH_DAY_OF_WEEK"] = collisions_cleaned["CRASH_DAY_OF_WEEK"].map(day_mapping)

# Assign months to numbers
month_mapping = {
    1: "January",
    2: "February",
    3: "March",
    4: "April",
    5: "May",
    6: "June",
    7: "July",
    8: "August",
    9: "September",
    10: "October",
    11: "November",
    12: "December"
}

collisions_cleaned["CRASH_MONTH"] = collisions_cleaned["CRASH_MONTH"].map(month_mapping)

# %%
pd.set_option('display.max_columns', None)
print(collisions_cleaned.head())
# Out:
#     CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# 1   2023-07-29                  30         TRAFFIC SIGNAL
# 2   2023-08-18                  30            NO CONTROLS
# 13  2023-07-29                  10            NO CONTROLS
# 14  2023-07-29                  30         TRAFFIC SIGNAL
# 20  2023-09-20                  15            NO CONTROLS
#
#         DEVICE_CONDITION WEATHER_CONDITION LIGHTING_CONDITION  \
# 1   FUNCTIONING PROPERLY             CLEAR           DAYLIGHT
# 2            NO CONTROLS             CLEAR           DAYLIGHT
# 13           NO CONTROLS           UNKNOWN            UNKNOWN
# 14  FUNCTIONING PROPERLY             CLEAR           DARKNESS
# 20           NO CONTROLS             CLEAR           DAYLIGHT
#
#                 FIRST_CRASH_TYPE                  TRAFFICWAY_TYPE  \
# 1           PARKED MOTOR VEHICLE  DIVIDED - W/MEDIAN (NOT RAISED)
# 2                   PEDALCYCLIST                      NOT DIVIDED
# 13                         ANGLE                      PARKING LOT
# 14  SIDESWIPE OPPOSITE DIRECTION                      NOT DIVIDED
# 20                  REAR TO SIDE                      PARKING LOT
#
#              ALIGNMENT ROADWAY_SURFACE_COND ROAD_DEFECT  REPORT_TYPE  \
# 1   STRAIGHT AND LEVEL                  DRY  NO DEFECTS     ON SCENE
# 2   STRAIGHT AND LEVEL                  DRY  NO DEFECTS     ON SCENE
# 13  STRAIGHT AND LEVEL              UNKNOWN     UNKNOWN  DESK REPORT
# 14  STRAIGHT AND LEVEL              UNKNOWN     UNKNOWN          NaN
# 20  STRAIGHT AND LEVEL                  DRY  NO DEFECTS  DESK REPORT
#
#                    CRASH_TYPE HIT_AND_RUN_I         DAMAGE  \
# 1      NO INJURY / DRIVE AWAY             Y         $1500+
# 2   INJURY / TOW DUE TO CRASH             N  $501 - $1,500
# 13     NO INJURY / DRIVE AWAY             Y  $501 - $1,500
# 14     NO INJURY / DRIVE AWAY             Y         $1500+
# 20     NO INJURY / DRIVE AWAY             Y         $1500+
#
#    DATE_POLICE_NOTIFIED                 PRIM_CONTRIBUTORY_CAUSE  \
# 1            2023-07-29  FAILING TO REDUCE SPEED TO AVOID CRASH
# 2            2023-08-18  FAILING TO REDUCE SPEED TO AVOID CRASH
# 13           2023-08-03                     UNABLE TO DETERMINE
# 14           2023-07-29                     UNABLE TO DETERMINE
# 20           2023-09-20                        IMPROPER BACKING
#
#                                SEC_CONTRIBUTORY_CAUSE  STREET_NO  \
# 1   OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELE...       2101
# 2                                 UNABLE TO DETERMINE       3422
# 13                                     NOT APPLICABLE       1320
# 14                                     NOT APPLICABLE        999
# 20                                     NOT APPLICABLE       8300
#
#    STREET_DIRECTION       STREET_NAME  NUM_UNITS        MOST_SEVERE_INJURY  \
# 1                 S       ASHLAND AVE          4   NO INDICATION OF INJURY
# 2                 N          LONG AVE          2  NONINCAPACITATING INJURY
# 13                E           47TH ST          2   NO INDICATION OF INJURY
# 14                N    CALIFORNIA AVE          2   NO INDICATION OF INJURY
# 20                S  STONY ISLAND AVE          2   NO INDICATION OF INJURY
#
#     INJURIES_TOTAL  INJURIES_FATAL  INJURIES_INCAPACITATING  \
# 1                0               0                        0
# 2                1               0                        0
# 13               0               0                        0
# 14               0               0                        0
# 20               0               0                        0
#
#     INJURIES_NON_INCAPACITATING  INJURIES_REPORTED_NOT_EVIDENT  \
# 1                             0                              0
# 2                             1                              0
# 13                            0                              0
# 14                            0                              0
# 20                            0                              0
#
#     INJURIES_NO_INDICATION  INJURIES_UNKNOWN  CRASH_HOUR CRASH_DAY_OF_WEEK  \
# 1                        1                 0          14          Saturday
# 2                        1                 0          17            Friday
# 13                       2                 0          14          Saturday
# 14                       2                 0           0          Saturday
# 20                       2                 0          12         Wednesday
#
#    CRASH_MONTH   LATITUDE  LONGITUDE                                  LOCATION
# 1         July  41.854120 -87.665902  POINT (-87.665902342962 41.854120262952)
# 2       August  41.942976 -87.761883  POINT (-87.761883496974 41.942975745006)
# 13        July  41.809781 -87.594213  POINT (-87.594212812011 41.809781151018)
# 14        July  41.899225 -87.696642  POINT (-87.696642374961 41.899224596015)
# 20   September  41.744152 -87.585945  POINT (-87.585945066953 41.744151639042)
